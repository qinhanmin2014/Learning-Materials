# %% [markdown]
# Sequence to sequence example in Keras (character-level).
#
# This script demonstrates how to implement a basic character-level
# sequence-to-sequence model. We apply it to translating
# short English sentences into short French sentences,
# character-by-character. Note that it is fairly unusual to
# do character-level machine translation, as word-level
# models are more common in this domain.
#
# **Summary of the algorithm**
#
# - We start with input sequences from a domain (e.g. English sentences)
#     and corresponding target sequences from another domain
#     (e.g. French sentences).
# - An encoder LSTM turns input sequences to 2 state vectors
#     (we keep the last LSTM state and discard the outputs).
# - A decoder LSTM is trained to turn the target sequences into
#     the same sequence but offset by one timestep in the future,
#     a training process called "teacher forcing" in this context.
#     It uses as initial state the state vectors from the encoder.
#     Effectively, the decoder learns to generate `targets[t+1...]`
#     given `targets[...t]`, conditioned on the input sequence.
# - In inference mode, when we want to decode unknown input sequences, we:
#     - Encode the input sequence into state vectors
#     - Start with a target sequence of size 1
#         (just the start-of-sequence character)
#     - Feed the state vectors and 1-char target sequence
#         to the decoder to produce predictions for the next character
#     - Sample the next character using these predictions
#         (we simply use argmax).
#     - Append the sampled character to the target sequence
#     - Repeat until we generate the end-of-sequence character or we
#         hit the character limit.
#
# **Data download**
#
# [English to French sentence pairs.
# ](http://www.manythings.org/anki/fra-eng.zip)
#
# [Lots of neat sentence pairs datasets.
# ](http://www.manythings.org/anki/)
#
# **References**
#
# - [Sequence to Sequence Learning with Neural Networks
#    ](https://arxiv.org/abs/1409.3215)
# - [Learning Phrase Representations using
#     RNN Encoder-Decoder for Statistical Machine Translation
#     ](https://arxiv.org/abs/1406.1078)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "3"
import tensorflow as tf
print(tf.__version__)
import keras
print(keras.__version__)
# Out:
# /home/sunxin/miniconda3/envs/qinhanmin-test/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/sunxin/miniconda3/envs/qinhanmin-test/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/sunxin/miniconda3/envs/qinhanmin-test/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/sunxin/miniconda3/envs/qinhanmin-test/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/sunxin/miniconda3/envs/qinhanmin-test/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/sunxin/miniconda3/envs/qinhanmin-test/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 1.13.2
# 2.2.4
# Using TensorFlow backend.

# %%
import numpy as np
from keras import models
from keras import layers

# %%
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = '../datasets/fra-eng/fra.txt'

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text, _ = line.split('\t')
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = '\t' + target_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

# %%
input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])
print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)
# Out:
# Number of samples: 10000
# Number of unique input tokens: 70
# Number of unique output tokens: 93
# Max sequence length for inputs: 16
# Max sequence length for outputs: 59

# %%
input_token_index = dict(
    [(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict(
    [(char, i) for i, char in enumerate(target_characters)])

# %%
encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')

# %%
for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.
    encoder_input_data[i, t + 1:, input_token_index[' ']] = 1.  # padding
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.
    decoder_input_data[i, t + 1:, target_token_index[' ']] = 1.
    decoder_target_data[i, t:, target_token_index[' ']] = 1.

# %%
# Define an input sequence and process it.
encoder_inputs = layers.Input(shape=(None, num_encoder_tokens))
encoder = layers.LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]
# Out:
# WARNING:tensorflow:From /home/sunxin/miniconda3/envs/qinhanmin-test/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = layers.Input(shape=(None, num_decoder_tokens))
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = layers.LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs,
                                     initial_state=encoder_states)
decoder_dense = layers.Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = models.Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
# Run training
model.compile(optimizer='rmsprop', loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2)
# Save model
model.save('s2s.h5')
# Out:
# WARNING:tensorflow:From /home/sunxin/miniconda3/envs/qinhanmin-test/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /home/sunxin/miniconda3/envs/qinhanmin-test/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/100
# 8000/8000 [==============================] - 12s 2ms/step - loss: 1.1991 - acc: 0.7235 - val_loss: 1.0658 - val_acc: 0.7007
# Epoch 2/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.8493 - acc: 0.7698 - val_loss: 0.8342 - val_acc: 0.7683
# Epoch 3/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.6656 - acc: 0.8107 - val_loss: 0.7074 - val_acc: 0.7950
# Epoch 4/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.5855 - acc: 0.8296 - val_loss: 0.6496 - val_acc: 0.8084
# Epoch 5/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.5416 - acc: 0.8414 - val_loss: 0.6206 - val_acc: 0.8172
# Epoch 6/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.5047 - acc: 0.8514 - val_loss: 0.5817 - val_acc: 0.8278
# Epoch 7/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.4758 - acc: 0.8592 - val_loss: 0.5535 - val_acc: 0.8361
# Epoch 8/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.4505 - acc: 0.8660 - val_loss: 0.5349 - val_acc: 0.8418
# Epoch 9/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.4292 - acc: 0.8720 - val_loss: 0.5136 - val_acc: 0.8472
# Epoch 10/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.4095 - acc: 0.8777 - val_loss: 0.5029 - val_acc: 0.8520
# Epoch 11/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.3913 - acc: 0.8827 - val_loss: 0.4866 - val_acc: 0.8561
# Epoch 12/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.3755 - acc: 0.8876 - val_loss: 0.4818 - val_acc: 0.8579
# Epoch 13/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.3611 - acc: 0.8917 - val_loss: 0.4727 - val_acc: 0.8604
# Epoch 14/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.3470 - acc: 0.8957 - val_loss: 0.4691 - val_acc: 0.8608
# Epoch 15/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.3342 - acc: 0.8992 - val_loss: 0.4619 - val_acc: 0.8632
# Epoch 16/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.3223 - acc: 0.9031 - val_loss: 0.4590 - val_acc: 0.8648
# Epoch 17/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.3110 - acc: 0.9063 - val_loss: 0.4525 - val_acc: 0.8666
# Epoch 18/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.2995 - acc: 0.9097 - val_loss: 0.4522 - val_acc: 0.8682
# Epoch 19/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.2896 - acc: 0.9124 - val_loss: 0.4500 - val_acc: 0.8688
# Epoch 20/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.2796 - acc: 0.9155 - val_loss: 0.4500 - val_acc: 0.8691
# Epoch 21/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.2702 - acc: 0.9181 - val_loss: 0.4479 - val_acc: 0.8695
# Epoch 22/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.2616 - acc: 0.9207 - val_loss: 0.4479 - val_acc: 0.8706
# Epoch 23/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.2531 - acc: 0.9232 - val_loss: 0.4486 - val_acc: 0.8708
# Epoch 24/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.2444 - acc: 0.9257 - val_loss: 0.4519 - val_acc: 0.8717
# Epoch 25/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.2370 - acc: 0.9277 - val_loss: 0.4523 - val_acc: 0.8719
# Epoch 26/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.2293 - acc: 0.9303 - val_loss: 0.4504 - val_acc: 0.8734
# Epoch 27/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.2223 - acc: 0.9323 - val_loss: 0.4559 - val_acc: 0.8731
# Epoch 28/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.2153 - acc: 0.9343 - val_loss: 0.4539 - val_acc: 0.8743
# Epoch 29/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.2086 - acc: 0.9365 - val_loss: 0.4571 - val_acc: 0.8739
# Epoch 30/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.2020 - acc: 0.9385 - val_loss: 0.4596 - val_acc: 0.8753
# Epoch 31/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.1958 - acc: 0.9403 - val_loss: 0.4656 - val_acc: 0.8739
# Epoch 32/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.1898 - acc: 0.9420 - val_loss: 0.4650 - val_acc: 0.8748
# Epoch 33/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.1843 - acc: 0.9439 - val_loss: 0.4691 - val_acc: 0.8751
# Epoch 34/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.1788 - acc: 0.9454 - val_loss: 0.4723 - val_acc: 0.8747
# Epoch 35/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.1732 - acc: 0.9469 - val_loss: 0.4820 - val_acc: 0.8739
# Epoch 36/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.1683 - acc: 0.9484 - val_loss: 0.4788 - val_acc: 0.8753
# Epoch 37/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.1630 - acc: 0.9501 - val_loss: 0.4929 - val_acc: 0.8739
# Epoch 38/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.1588 - acc: 0.9514 - val_loss: 0.4935 - val_acc: 0.8741
# Epoch 39/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.1541 - acc: 0.9527 - val_loss: 0.4892 - val_acc: 0.8754
# Epoch 40/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.1500 - acc: 0.9542 - val_loss: 0.5003 - val_acc: 0.8743
# Epoch 41/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.1459 - acc: 0.9553 - val_loss: 0.5041 - val_acc: 0.8740
# Epoch 42/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.1417 - acc: 0.9563 - val_loss: 0.5082 - val_acc: 0.8739
# Epoch 43/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.1379 - acc: 0.9576 - val_loss: 0.5139 - val_acc: 0.8747
# Epoch 44/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.1342 - acc: 0.9588 - val_loss: 0.5181 - val_acc: 0.8733
# Epoch 45/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.1307 - acc: 0.9597 - val_loss: 0.5234 - val_acc: 0.8737
# Epoch 46/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.1275 - acc: 0.9605 - val_loss: 0.5243 - val_acc: 0.8738
# Epoch 47/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.1242 - acc: 0.9615 - val_loss: 0.5292 - val_acc: 0.8735
# Epoch 48/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.1209 - acc: 0.9626 - val_loss: 0.5345 - val_acc: 0.8742
# Epoch 49/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.1181 - acc: 0.9634 - val_loss: 0.5427 - val_acc: 0.8739
# Epoch 50/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.1150 - acc: 0.9640 - val_loss: 0.5511 - val_acc: 0.8734
# Epoch 51/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.1123 - acc: 0.9652 - val_loss: 0.5496 - val_acc: 0.8737
# Epoch 52/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.1096 - acc: 0.9659 - val_loss: 0.5561 - val_acc: 0.8726
# Epoch 53/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.1067 - acc: 0.9666 - val_loss: 0.5624 - val_acc: 0.8731
# Epoch 54/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.1042 - acc: 0.9676 - val_loss: 0.5667 - val_acc: 0.8727
# Epoch 55/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.1017 - acc: 0.9683 - val_loss: 0.5736 - val_acc: 0.8729
# Epoch 56/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0995 - acc: 0.9687 - val_loss: 0.5831 - val_acc: 0.8725
# Epoch 57/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0972 - acc: 0.9695 - val_loss: 0.5867 - val_acc: 0.8727
# Epoch 58/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0950 - acc: 0.9701 - val_loss: 0.5885 - val_acc: 0.8717
# Epoch 59/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0924 - acc: 0.9708 - val_loss: 0.5941 - val_acc: 0.8720
# Epoch 60/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0912 - acc: 0.9711 - val_loss: 0.6013 - val_acc: 0.8723
# Epoch 61/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0887 - acc: 0.9718 - val_loss: 0.6096 - val_acc: 0.8712
# Epoch 62/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0868 - acc: 0.9724 - val_loss: 0.6135 - val_acc: 0.8709
# Epoch 63/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0849 - acc: 0.9729 - val_loss: 0.6164 - val_acc: 0.8710
# Epoch 64/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0826 - acc: 0.9735 - val_loss: 0.6100 - val_acc: 0.8710
# Epoch 65/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0814 - acc: 0.9739 - val_loss: 0.6250 - val_acc: 0.8713
# Epoch 66/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0799 - acc: 0.9743 - val_loss: 0.6277 - val_acc: 0.8718
# Epoch 67/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0778 - acc: 0.9751 - val_loss: 0.6377 - val_acc: 0.8712
# Epoch 68/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0765 - acc: 0.9753 - val_loss: 0.6349 - val_acc: 0.8717
# Epoch 69/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0749 - acc: 0.9759 - val_loss: 0.6413 - val_acc: 0.8712
# Epoch 70/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0735 - acc: 0.9763 - val_loss: 0.6447 - val_acc: 0.8710
# Epoch 71/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0720 - acc: 0.9766 - val_loss: 0.6498 - val_acc: 0.8718
# Epoch 72/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0707 - acc: 0.9771 - val_loss: 0.6534 - val_acc: 0.8717
# Epoch 73/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0690 - acc: 0.9776 - val_loss: 0.6576 - val_acc: 0.8711
# Epoch 74/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0675 - acc: 0.9781 - val_loss: 0.6656 - val_acc: 0.8713
# Epoch 75/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0666 - acc: 0.9781 - val_loss: 0.6671 - val_acc: 0.8703
# Epoch 76/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0651 - acc: 0.9787 - val_loss: 0.6679 - val_acc: 0.8711
# Epoch 77/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0639 - acc: 0.9789 - val_loss: 0.6772 - val_acc: 0.8711
# Epoch 78/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0633 - acc: 0.9792 - val_loss: 0.6811 - val_acc: 0.8708
# Epoch 79/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0619 - acc: 0.9794 - val_loss: 0.6828 - val_acc: 0.8706
# Epoch 80/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0606 - acc: 0.9800 - val_loss: 0.6852 - val_acc: 0.8704
# Epoch 81/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0598 - acc: 0.9801 - val_loss: 0.6864 - val_acc: 0.8709
# Epoch 82/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0588 - acc: 0.9805 - val_loss: 0.6950 - val_acc: 0.8710
# Epoch 83/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0577 - acc: 0.9808 - val_loss: 0.6943 - val_acc: 0.8707
# Epoch 84/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0567 - acc: 0.9810 - val_loss: 0.7055 - val_acc: 0.8699
# Epoch 85/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0559 - acc: 0.9811 - val_loss: 0.7066 - val_acc: 0.8697
# Epoch 86/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0552 - acc: 0.9814 - val_loss: 0.7066 - val_acc: 0.8700
# Epoch 87/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0540 - acc: 0.9820 - val_loss: 0.7145 - val_acc: 0.8711
# Epoch 88/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0532 - acc: 0.9821 - val_loss: 0.7073 - val_acc: 0.8703
# Epoch 89/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0525 - acc: 0.9822 - val_loss: 0.7206 - val_acc: 0.8707
# Epoch 90/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0514 - acc: 0.9826 - val_loss: 0.7241 - val_acc: 0.8704
# Epoch 91/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0510 - acc: 0.9826 - val_loss: 0.7302 - val_acc: 0.8694
# Epoch 92/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0502 - acc: 0.9829 - val_loss: 0.7230 - val_acc: 0.8707
# Epoch 93/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0493 - acc: 0.9832 - val_loss: 0.7285 - val_acc: 0.8705
# Epoch 94/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0487 - acc: 0.9832 - val_loss: 0.7252 - val_acc: 0.8703
# Epoch 95/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0478 - acc: 0.9835 - val_loss: 0.7414 - val_acc: 0.8695
# Epoch 96/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0474 - acc: 0.9836 - val_loss: 0.7362 - val_acc: 0.8704
# Epoch 97/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0468 - acc: 0.9838 - val_loss: 0.7433 - val_acc: 0.8699
# Epoch 98/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0464 - acc: 0.9839 - val_loss: 0.7439 - val_acc: 0.8708
# Epoch 99/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0454 - acc: 0.9842 - val_loss: 0.7447 - val_acc: 0.8702
# Epoch 100/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.0449 - acc: 0.9843 - val_loss: 0.7540 - val_acc: 0.8695
# /home/sunxin/miniconda3/envs/qinhanmin-test/lib/python3.7/site-packages/keras/engine/network.py:877: UserWarning: Layer lstm_2 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1/while/Exit_2:0' shape=(?, 256) dtype=float32>, <tf.Tensor 'lstm_1/while/Exit_3:0' shape=(?, 256) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '

# %%
# Define sampling models
encoder_model = models.Model(encoder_inputs, encoder_states)

decoder_state_input_h = layers.Input(shape=(latent_dim,))
decoder_state_input_c = layers.Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = models.Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# %%
# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict(
    (i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict(
    (i, char) for char, i in target_token_index.items())

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index['\t']] = 1.

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    # stop_condition = False
    decoded_sentence = ''
    # while not stop_condition:
    while True:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        # decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        # if (sampled_char == '\n' or
        #    len(decoded_sentence) > max_decoder_seq_length):
        #     stop_condition = True
        if sampled_char == "\n":
            break
        decoded_sentence += sampled_char
        if len(decoded_sentence) >= max_decoder_seq_length:
            break

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %%
for seq_index in range(100):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', input_texts[seq_index])
    print('Decoded sentence:', decoded_sentence)
    print('Target sentence:', target_texts[seq_index][1:-1])
# Out:
# -
# Input sentence: Go.
# Decoded sentence: Va !
# Target sentence: Va !
# -
# Input sentence: Hi.
# Decoded sentence: Salut.
# Target sentence: Salut !
# -
# Input sentence: Hi.
# Decoded sentence: Salut.
# Target sentence: Salut.
# -
# Input sentence: Run!
# Decoded sentence: Courez !
# Target sentence: Cours !
# -
# Input sentence: Run!
# Decoded sentence: Courez !
# Target sentence: Courez !
# -
# Input sentence: Who?
# Decoded sentence: Qui ?
# Target sentence: Qui ?
# -
# Input sentence: Wow!
# Decoded sentence: Ça alors !
# Target sentence: Ça alors !
# -
# Input sentence: Fire!
# Decoded sentence: Au feu !
# Target sentence: Au feu !
# -
# Input sentence: Help!
# Decoded sentence: À l'aide !
# Target sentence: À l'aide !
# -
# Input sentence: Jump.
# Decoded sentence: Saute.
# Target sentence: Saute.
# -
# Input sentence: Stop!
# Decoded sentence: Arrête-toi !
# Target sentence: Ça suffit !
# -
# Input sentence: Stop!
# Decoded sentence: Arrête-toi !
# Target sentence: Stop !
# -
# Input sentence: Stop!
# Decoded sentence: Arrête-toi !
# Target sentence: Arrête-toi !
# -
# Input sentence: Wait!
# Decoded sentence: Attendez !
# Target sentence: Attends !
# -
# Input sentence: Wait!
# Decoded sentence: Attendez !
# Target sentence: Attendez !
# -
# Input sentence: Go on.
# Decoded sentence: Poursuivez.
# Target sentence: Poursuis.
# -
# Input sentence: Go on.
# Decoded sentence: Poursuivez.
# Target sentence: Continuez.
# -
# Input sentence: Go on.
# Decoded sentence: Poursuivez.
# Target sentence: Poursuivez.
# -
# Input sentence: Hello!
# Decoded sentence: Bonjour !
# Target sentence: Bonjour !
# -
# Input sentence: Hello!
# Decoded sentence: Bonjour !
# Target sentence: Salut !
# -
# Input sentence: I see.
# Decoded sentence: Je comprends.
# Target sentence: Je comprends.
# -
# Input sentence: I try.
# Decoded sentence: J'essaye.
# Target sentence: J'essaye.
# -
# Input sentence: I won!
# Decoded sentence: J'ai gagné !
# Target sentence: J'ai gagné !
# -
# Input sentence: I won!
# Decoded sentence: J'ai gagné !
# Target sentence: Je l'ai emporté !
# -
# Input sentence: I won.
# Decoded sentence: Je me suis raisonne.
# Target sentence: J’ai gagné.
# -
# Input sentence: Oh no!
# Decoded sentence: Oh non !
# Target sentence: Oh non !
# -
# Input sentence: Attack!
# Decoded sentence: Attaquez !
# Target sentence: Attaque !
# -
# Input sentence: Attack!
# Decoded sentence: Attaquez !
# Target sentence: Attaquez !
# -
# Input sentence: Cheers!
# Decoded sentence: Merci !
# Target sentence: Santé !
# -
# Input sentence: Cheers!
# Decoded sentence: Merci !
# Target sentence: À votre santé !
# -
# Input sentence: Cheers!
# Decoded sentence: Merci !
# Target sentence: Merci !
# -
# Input sentence: Cheers!
# Decoded sentence: Merci !
# Target sentence: Tchin-tchin !
# -
# Input sentence: Get up.
# Decoded sentence: Lève-toi.
# Target sentence: Lève-toi.
# -
# Input sentence: Go now.
# Decoded sentence: Vas-y maintenant.
# Target sentence: Va, maintenant.
# -
# Input sentence: Go now.
# Decoded sentence: Vas-y maintenant.
# Target sentence: Allez-y maintenant.
# -
# Input sentence: Go now.
# Decoded sentence: Vas-y maintenant.
# Target sentence: Vas-y maintenant.
# -
# Input sentence: Got it!
# Decoded sentence: J'ai pigé !
# Target sentence: J'ai pigé !
# -
# Input sentence: Got it!
# Decoded sentence: J'ai pigé !
# Target sentence: Compris !
# -
# Input sentence: Got it?
# Decoded sentence: Pigé ?
# Target sentence: Pigé ?
# -
# Input sentence: Got it?
# Decoded sentence: Pigé ?
# Target sentence: Compris ?
# -
# Input sentence: Got it?
# Decoded sentence: Pigé ?
# Target sentence: T'as capté ?
# -
# Input sentence: Hop in.
# Decoded sentence: Montez.
# Target sentence: Monte.
# -
# Input sentence: Hop in.
# Decoded sentence: Montez.
# Target sentence: Montez.
# -
# Input sentence: Hug me.
# Decoded sentence: Serre-moi dans tes bras !
# Target sentence: Serre-moi dans tes bras !
# -
# Input sentence: Hug me.
# Decoded sentence: Serre-moi dans tes bras !
# Target sentence: Serrez-moi dans vos bras !
# -
# Input sentence: I fell.
# Decoded sentence: Je suis tombé.
# Target sentence: Je suis tombée.
# -
# Input sentence: I fell.
# Decoded sentence: Je suis tombé.
# Target sentence: Je suis tombé.
# -
# Input sentence: I know.
# Decoded sentence: Je sais.
# Target sentence: Je sais.
# -
# Input sentence: I left.
# Decoded sentence: Je suis parti.
# Target sentence: Je suis parti.
# -
# Input sentence: I left.
# Decoded sentence: Je suis parti.
# Target sentence: Je suis partie.
# -
# Input sentence: I lost.
# Decoded sentence: J'ai perdu.
# Target sentence: J'ai perdu.
# -
# Input sentence: I paid.
# Decoded sentence: J’ai payé.
# Target sentence: J’ai payé.
# -
# Input sentence: I'm 19.
# Decoded sentence: J'ai remporté.
# Target sentence: J'ai 19 ans.
# -
# Input sentence: I'm OK.
# Decoded sentence: Je vais bien.
# Target sentence: Je vais bien.
# -
# Input sentence: I'm OK.
# Decoded sentence: Je vais bien.
# Target sentence: Ça va.
# -
# Input sentence: Listen.
# Decoded sentence: Écoutez !
# Target sentence: Écoutez !
# -
# Input sentence: No way!
# Decoded sentence: En aucun cas.
# Target sentence: C'est pas possible !
# -
# Input sentence: No way!
# Decoded sentence: En aucun cas.
# Target sentence: Impossible !
# -
# Input sentence: No way!
# Decoded sentence: En aucun cas.
# Target sentence: En aucun cas.
# -
# Input sentence: No way!
# Decoded sentence: En aucun cas.
# Target sentence: Sans façons !
# -
# Input sentence: No way!
# Decoded sentence: En aucun cas.
# Target sentence: C'est hors de question !
# -
# Input sentence: No way!
# Decoded sentence: En aucun cas.
# Target sentence: Il n'en est pas question !
# -
# Input sentence: No way!
# Decoded sentence: En aucun cas.
# Target sentence: C'est exclu !
# -
# Input sentence: No way!
# Decoded sentence: En aucun cas.
# Target sentence: En aucune manière !
# -
# Input sentence: No way!
# Decoded sentence: En aucun cas.
# Target sentence: Hors de question !
# -
# Input sentence: Really?
# Decoded sentence: Vrai ?
# Target sentence: Vraiment ?
# -
# Input sentence: Really?
# Decoded sentence: Vrai ?
# Target sentence: Vrai ?
# -
# Input sentence: Really?
# Decoded sentence: Vrai ?
# Target sentence: Ah bon ?
# -
# Input sentence: Thanks.
# Decoded sentence: Merci !
# Target sentence: Merci !
# -
# Input sentence: We try.
# Decoded sentence: On essaye.
# Target sentence: On essaye.
# -
# Input sentence: We won.
# Decoded sentence: Nous avons gagné.
# Target sentence: Nous avons gagné.
# -
# Input sentence: We won.
# Decoded sentence: Nous avons gagné.
# Target sentence: Nous gagnâmes.
# -
# Input sentence: We won.
# Decoded sentence: Nous avons gagné.
# Target sentence: Nous l'avons emporté.
# -
# Input sentence: We won.
# Decoded sentence: Nous avons gagné.
# Target sentence: Nous l'emportâmes.
# -
# Input sentence: Ask Tom.
# Decoded sentence: Demande à Tom.
# Target sentence: Demande à Tom.
# -
# Input sentence: Awesome!
# Decoded sentence: Fantastique !
# Target sentence: Fantastique !
# -
# Input sentence: Be calm.
# Decoded sentence: Soyez calme !
# Target sentence: Sois calme !
# -
# Input sentence: Be calm.
# Decoded sentence: Soyez calme !
# Target sentence: Soyez calme !
# -
# Input sentence: Be calm.
# Decoded sentence: Soyez calme !
# Target sentence: Soyez calmes !
# -
# Input sentence: Be cool.
# Decoded sentence: Sois détendreux !
# Target sentence: Sois détendu !
# -
# Input sentence: Be fair.
# Decoded sentence: Sois équitable !
# Target sentence: Sois juste !
# -
# Input sentence: Be fair.
# Decoded sentence: Sois équitable !
# Target sentence: Soyez juste !
# -
# Input sentence: Be fair.
# Decoded sentence: Sois équitable !
# Target sentence: Soyez justes !
# -
# Input sentence: Be fair.
# Decoded sentence: Sois équitable !
# Target sentence: Sois équitable !
# -
# Input sentence: Be fair.
# Decoded sentence: Sois équitable !
# Target sentence: Soyez équitable !
# -
# Input sentence: Be fair.
# Decoded sentence: Sois équitable !
# Target sentence: Soyez équitables !
# -
# Input sentence: Be kind.
# Decoded sentence: Sois gentil.
# Target sentence: Sois gentil.
# -
# Input sentence: Be nice.
# Decoded sentence: Sois gentille !
# Target sentence: Sois gentil !
# -
# Input sentence: Be nice.
# Decoded sentence: Sois gentille !
# Target sentence: Sois gentille !
# -
# Input sentence: Be nice.
# Decoded sentence: Sois gentille !
# Target sentence: Soyez gentil !
# -
# Input sentence: Be nice.
# Decoded sentence: Sois gentille !
# Target sentence: Soyez gentille !
# -
# Input sentence: Be nice.
# Decoded sentence: Sois gentille !
# Target sentence: Soyez gentils !
# -
# Input sentence: Be nice.
# Decoded sentence: Sois gentille !
# Target sentence: Soyez gentilles !
# -
# Input sentence: Beat it.
# Decoded sentence: Dégage !
# Target sentence: Dégage !
# -
# Input sentence: Call me.
# Decoded sentence: Appellez-moi !
# Target sentence: Appelle-moi !
# -
# Input sentence: Call me.
# Decoded sentence: Appellez-moi !
# Target sentence: Appellez-moi !
# -
# Input sentence: Call us.
# Decoded sentence: Appelez-nous !
# Target sentence: Appelle-nous !
# -
# Input sentence: Call us.
# Decoded sentence: Appelez-nous !
# Target sentence: Appelez-nous !
# -
# Input sentence: Come in.
# Decoded sentence: Entre !
# Target sentence: Entrez !
# -
# Input sentence: Come in.
# Decoded sentence: Entre !
# Target sentence: Entre.
